# %% [markdown]
# # Rain in Australia
# - Predict next-day rain by training classification models on the target variable RainTomorrow.
# - This dataset contains about 10 years of daily weather observations from many locations across Australia.
# - RainTomorrow is the target variable to predict. It means -- did it rain the next day, Yes or No? This column is Yes if the rain for that day was 1mm or more.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("weatherAUS.csv")
data.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8         No
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3         No
# 2       1007.6       1008.7       NaN       2.0     21.0     23.2         No
# 3       1017.6       1012.8       NaN       NaN     18.1     26.5         No
# 4       1010.8       1006.0       7.0       8.0     17.8     29.7         No
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
#
# [5 rows x 23 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
#  16  Pressure3pm    130432 non-null  float64
#  17  Cloud9am       89572 non-null   float64
#  18  Cloud3pm       86102 non-null   float64
#  19  Temp9am        143693 non-null  float64
#  20  Temp3pm        141851 non-null  float64
#  21  RainToday      142199 non-null  object
#  22  RainTomorrow   142193 non-null  object
# dtypes: float64(16), object(7)
# memory usage: 25.5+ MB

# %% [markdown]
# # 1. Nan value 분석

# %%
data.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
#RainTomorrow에 결측값 존재시 해당 행 제거. (Target이니까)
data = data.dropna(subset=['RainTomorrow'])

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['RainTomorrow'] = le.fit_transform(data['RainTomorrow'])

# %%
sns.barplot(y=data.isnull().sum().index, x=data.isnull().mean().values)
# Out:
# <AxesSubplot: >

# %%
data['RainTomorrow'].value_counts() # 0=No,1=Yes
# Out:
# 0    110316
# 1     31877
# Name: RainTomorrow, dtype: int64

# %%
Not_rain, rain = data['RainTomorrow'].value_counts() 
total_ratio = rain / Not_rain
total_ratio
# Out:
# 0.288960803509917

# %% [markdown]
# ##### 1. numeric data

# %%
#replace nan to -1 about numeric datas
numeric_features = data.select_dtypes(include=[np.number])

#get features which have more than one NaN value 
#loc() : 인덱스를 통해 행 데이터를 가져옴.
numeric_features = numeric_features.loc[:, numeric_features.isna().sum() > 0]

nan_values = {} #set

for col in numeric_features.columns:
    if data[col].min() >= 0:
        nan_values[col] = -1
        data[col].fillna(nan_values[col], inplace = True)
    else: 
        nan_values[col] = int(data[col].min()) -1 #replace nan with new min (made) value
        data[col].fillna(nan_values[col], inplace = True)
data[numeric_features.columns].isnull().sum()
# Out:
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustSpeed    0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# dtype: int64

# %%
nan_values
# Out:
# {'MinTemp': -9,
#  'MaxTemp': -5,
#  'Rainfall': -1,
#  'Evaporation': -1,
#  'Sunshine': -1,
#  'WindGustSpeed': -1,
#  'WindSpeed9am': -1,
#  'WindSpeed3pm': -1,
#  'Humidity9am': -1,
#  'Humidity3pm': -1,
#  'Pressure9am': -1,
#  'Pressure3pm': -1,
#  'Cloud9am': -1,
#  'Cloud3pm': -1,
#  'Temp9am': -8,
#  'Temp3pm': -6}

# %% [markdown]
# ##### 2. categorical data

# %%
category_features = data.select_dtypes(include=[object])
category_features = category_features.loc[:, category_features.isnull().sum() > 0]
category_features
# Out:
#        WindGustDir WindDir9am WindDir3pm RainToday
# 0                W          W        WNW        No
# 1              WNW        NNW        WSW        No
# 2              WSW          W        WSW        No
# 3               NE         SE          E        No
# 4                W        ENE         NW        No
# ...            ...        ...        ...       ...
# 145454           E        ESE          E        No
# 145455           E         SE        ENE        No
# 145456         NNW         SE          N        No
# 145457           N         SE        WNW        No
# 145458          SE        SSE          N        No
#
# [142193 rows x 4 columns]

# %%
# data['Cloud9am'].replace(np.nan, -1, inplace=True)
# data['Cloud3pm'].replace(np.nan, -1, inplace=True)
#'Cloud9am': -1, 'Cloud3pm': -1

#print(data['Cloud9am'].unique()) = [ 8. -1.  7.  1.  0.  5.  4.  2.  6.  3.  9.]
bars = []
x = []
for i in data['Cloud9am'].unique():
    filtered_data = data[data['Cloud9am'] == i].value_counts('RainTomorrow')
    no, yes = filtered_data.get(0, 0), filtered_data.get(1, 0)
    bars.append([no, yes])
    x.append(i)

bars = np.array(bars)
x = np.array(x)

#plot two bars nearly 
delta = 0.35
plt.bar(x-delta, bars[:,0], delta, align='edge', label='No') #No
plt.bar(x, bars[:,1], delta, align='edge', label='Yes') #Yes

plt.xlabel('Cloud9am')
plt.legend()

plt.twinx() #x축만 공유하고 y축은 따로 사용
plt.scatter(x, bars[:, 1]/bars[:, 0], color='r', label='ratio')
plt.legend()
plt.axhline(total_ratio, color='black', label='total ratio') #수직 수평선 그리기
plt.legend()

plt.xticks(x, x)
plt.show()

# %%
bars = []
x = []
for i in data['Cloud3pm'].unique():
    filtered_data = data[data['Cloud3pm'] == i].value_counts('RainTomorrow')
    no, yes = filtered_data.get(0, 0), filtered_data.get(1, 0)
    bars.append([no, yes])
    x.append(i)

bars = np.array(bars)
x = np.array(x)

#plot two bars nearly 
delta = 0.35
plt.bar(x-delta, bars[:,0], delta, align='edge', label='No') #No
plt.bar(x, bars[:,1], delta, align='edge', label='Yes') #Yes

plt.xlabel('Cloud3pm')
plt.legend()

plt.twinx() #x축만 공유하고 y축은 따로 사용
plt.scatter(x, bars[:, 1]/bars[:, 0], color='r', label='ratio')
plt.legend()
plt.axhline(total_ratio, color='black', label='total ratio') #수직 수평선 그리기
plt.legend()

plt.xticks(x, x)
plt.show()

# %% [markdown]
# - **그래프로부터 알 수 있는 사실**
# : Cloud9am이 NaN값인 경우에 대한 Yes/No ratio ≒ total ratio
# : Cloud3pm이 NaN값인 경우에 대한 Yes/No ratio ≒ total ratio

# %%
data['Sunshine']
# Out:
# 0        -1.0
# 1        -1.0
# 2        -1.0
# 3        -1.0
# 4        -1.0
#          ...
# 145454   -1.0
# 145455   -1.0
# 145456   -1.0
# 145457   -1.0
# 145458   -1.0
# Name: Sunshine, Length: 142193, dtype: float64

# %% [raw]
# 커널 밀도 추정(KDE: Kernel Density Estimator)이란
# 쉽게 얘기하면 히스토그램 같은 분포를 스무딩~ 부드럽게 곡선화(?) 시켜서 그려주는 거

# %%
sns.kdeplot(data=data, x='Sunshine', hue='RainTomorrow')
# Out:
# <AxesSubplot: xlabel='Sunshine', ylabel='Density'>

# %%
sns.kdeplot(data=data, x='Evaporation', hue='RainTomorrow')
# Out:
# <AxesSubplot: xlabel='Evaporation', ylabel='Density'>

# %% [markdown]
# # 이상치 확인 및 제거

# %%
data = pd.read_csv("weatherAUS.csv")
data = data.dropna(subset=['RainTomorrow'])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import sklearn 
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor


from sklearn.metrics import mean_absolute_error
from sklearn.metrics import accuracy_score

import zipfile

# %%
mpl.rcParams['figure.figsize'] = (10, 8)
mpl.rcParams['font.size'] = 10

# %%
data.boxplot(column='WindSpeed9am', by='RainTomorrow')
# Out:
# <AxesSubplot: title={'center': 'WindSpeed9am'}, xlabel='RainTomorrow'>

# %%
numerical_cols = data.select_dtypes(include=np.number).columns
sigma = 4
new_data = data.copy()

for col in numerical_cols:
    less_than_sigma = max(data[col].mean() - sigma*data[col].std(), data[col].min())
    greater_than_sigma = min(data[col].mean() + sigma*data[col].std(), data[col].max())
    print(f'Col: {col}, {less_than_sigma, greater_than_sigma}')
    new_data = new_data.query(
        f'{col} > {less_than_sigma} and {col} < {greater_than_sigma}'
    )
    
else:
    print(new_data.shape)
# Out:
# Col: MinTemp, (-8.5, 33.9)
# Col: MaxTemp, (-4.8, 48.1)
# Col: Rainfall, (0.0, 36.21066574477668)
# Col: Evaporation, (0.0, 22.223970251929742)
# Col: Sunshine, (0.0, 14.5)
# Col: WindGustSpeed, (6.0, 94.33949471952724)
# Col: WindSpeed9am, (0.0, 49.575336393932005)
# Col: WindSpeed3pm, (0.0, 53.85095600673932)
# Col: Humidity9am, (0.0, 100.0)
# Col: Humidity3pm, (0.0, 100.0)
# Col: Pressure9am, (989.2318555698819, 1041.0)
# Col: Pressure3pm, (987.1114964039162, 1039.6)
# Col: Cloud9am, (0.0, 9.0)
# Col: Cloud3pm, (0.0, 9.0)
# Col: Temp9am, (-7.2, 40.2)
# Col: Temp3pm, (-5.4, 46.7)
# (17086, 23)

# %%
new_data.boxplot(column='WindSpeed9am', by='RainTomorrow')
# Out:
# <AxesSubplot: title={'center': 'WindSpeed9am'}, xlabel='RainTomorrow'>

# %%
# Data distribution before and after removing outliers
sns.kdeplot(data['WindSpeed9am'], fill=True) #이상치 제거 전 WindSpeed9am값 밀도 분포
sns.kdeplot(new_data['WindSpeed9am'], fill=True)

plt.axvline(data['WindSpeed9am'].mean(), color='blue')
plt.axvline(new_data['WindSpeed9am'].mean(), color='r')
plt.legend(['Original', 'New'])

# %% [markdown]
# - 상황 해석
# : (값이 큰) outlier 제거 -> 기울기의 절댓값 더 1에 가까워짐.(이전보다 우측으로 치우쳐짐)
# => 따라서 succeed

# %% [markdown]
# # Feature Distribution
# https://towardsdatascience.com/are-you-using-feature-distributions-to-detect-outliers-48e2ae3309

# %%
#1. numerical
tmp_dist = sns.kdeplot(data=new_data, x='Humidity3pm', hue='RainTomorrow')

# %%
#tmp_dist = sns.kdeplot(data=new_data, x='Humidity3pm', hue='RainTomorrow')
line = tmp_dist.lines[0]
line2 = tmp_dist.lines[1]

x1, y1 = line.get_data() #Yes
x2, y2 = line2.get_data() #No

plt.plot(x1, y1, label='Rain')
plt.plot(x2, y2, label='No Rain')

plt.legend()

# %% [markdown]
# ![KakaoTalk_20230109_173619841.png](attachment:KakaoTalk_20230109_173619841.png)

# %%
#2. Categorical
count = sns.countplot(data=new_data, x='WindDir3pm', hue='RainTomorrow')

# %%
values = count.patches
#Every bar (and its corresponding background area) is known as a patch within the bar chart object

# %%
keys = count.get_xticklabels()
keys
# Out:
# [Text(0, 0, 'NW'),
#  Text(1, 0, 'SW'),
#  Text(2, 0, 'SSW'),
#  Text(3, 0, 'E'),
#  Text(4, 0, 'ESE'),
#  Text(5, 0, 'NE'),
#  Text(6, 0, 'S'),
#  Text(7, 0, 'ENE'),
#  Text(8, 0, 'WNW'),
#  Text(9, 0, 'W'),
#  Text(10, 0, 'N'),
#  Text(11, 0, 'SSE'),
#  Text(12, 0, 'NNE'),
#  Text(13, 0, 'WSW'),
#  Text(14, 0, 'NNW'),
#  Text(15, 0, 'SE')]

# %%
bars = {}
for i in range(len(keys)):
    yes_value = values[i].get_height()
    no_value = values[i + len(keys)].get_height()
    bars[keys[i].get_text()] = {0: no_value, 1: yes_value}
bars
# Out:
# {'NW': {0: 398.0, 1: 470.0},
#  'SW': {0: 410.0, 1: 997.0},
#  'SSW': {0: 406.0, 1: 829.0},
#  'E': {0: 321.0, 1: 700.0},
#  'ESE': {0: 299.0, 1: 687.0},
#  'NE': {0: 216.0, 1: 415.0},
#  'S': {0: 417.0, 1: 1048.0},
#  'ENE': {0: 280.0, 1: 558.0},
#  'WNW': {0: 586.0, 1: 625.0},
#  'W': {0: 661.0, 1: 947.0},
#  'N': {0: 386.0, 1: 437.0},
#  'SSE': {0: 340.0, 1: 711.0},
#  'NNE': {0: 220.0, 1: 258.0},
#  'WSW': {0: 533.0, 1: 953.0},
#  'NNW': {0: 305.0, 1: 391.0},
#  'SE': {0: 441.0, 1: 840.0}}

# %%
# 0~!사이로 값을 축소 시키기 위해 ratio 도입
norm_0 = sum([bars[key][0] for key in bars.keys()])
norm_1 = sum([bars[key][1] for key in bars.keys()])
for key in bars.keys():
    bars[key][0] = bars[key][0]/norm_0
    bars[key][1] = bars[key][1]/norm_1   
bars
# Out:
# {'NW': {0: 0.06399742723910597, 1: 0.04325418737345849},
#  'SW': {0: 0.06592699790963177, 1: 0.0917540953432726},
#  'SSW': {0: 0.06528380768612317, 1: 0.0762930241119087},
#  'E': {0: 0.05161601543656536, 1: 0.06442113013068286},
#  'ESE': {0: 0.04807846920726805, 1: 0.06322473771397018},
#  'NE': {0: 0.03473227206946455, 1: 0.038192527148904844},
#  'S': {0: 0.06705258080077182, 1: 0.09644763482422235},
#  'ENE': {0: 0.045023315645602184, 1: 0.05135284373274434},
#  'WNW': {0: 0.09422736774401029, 1: 0.0575188661881097},
#  'W': {0: 0.1062871844347966, 1: 0.08715258604822382},
#  'N': {0: 0.06206785656858016, 1: 0.0402171912387263},
#  'SSE': {0: 0.054671168998231226, 1: 0.06543346217559359},
#  'NNE': {0: 0.03537546229297315, 1: 0.023743787962451683},
#  'WSW': {0: 0.0857050972825213, 1: 0.08770476716362967},
#  'NNW': {0: 0.04904325454253095, 1: 0.03598380268728143},
#  'SE': {0: 0.07091172214182344, 1: 0.07730535615681944}}

# %% [markdown]
# # 2. impute

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17086 entries, 6068 to 142278
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           17086 non-null  object
#  1   Location       17086 non-null  object
#  2   MinTemp        17086 non-null  float64
#  3   MaxTemp        17086 non-null  float64
#  4   Rainfall       17086 non-null  float64
#  5   Evaporation    17086 non-null  float64
#  6   Sunshine       17086 non-null  float64
#  7   WindGustDir    17082 non-null  object
#  8   WindGustSpeed  17086 non-null  float64
#  9   WindDir9am     17084 non-null  object
#  10  WindDir3pm     17085 non-null  object
#  11  WindSpeed9am   17086 non-null  float64
#  12  WindSpeed3pm   17086 non-null  float64
#  13  Humidity9am    17086 non-null  float64
#  14  Humidity3pm    17086 non-null  float64
#  15  Pressure9am    17086 non-null  float64
#  16  Pressure3pm    17086 non-null  float64
#  17  Cloud9am       17086 non-null  float64
#  18  Cloud3pm       17086 non-null  float64
#  19  Temp9am        17086 non-null  float64
#  20  Temp3pm        17086 non-null  float64
#  21  RainToday      17086 non-null  object
#  22  RainTomorrow   17086 non-null  object
# dtypes: float64(16), object(7)
# memory usage: 3.1+ MB

# %%
new_data = data.copy()

# %%
x, y = {}, {}
null_columns = new_data.columns[data.isnull().any()]
catetorical_cols = new_data[null_columns].select_dtypes(include='object').columns
float_cols = new_data[null_columns].select_dtypes(include=np.number).columns
int_cols = new_data.loc[:, new_data.nunique() < 150].select_dtypes(include=np.number).columns
float_cols = float_cols.drop(int_cols)

print(null_columns)
print(catetorical_cols)
print(float_cols)
print(int_cols)

def dist_categorical(data, col):
    assert col in catetorical_cols, f'{col} is not a categorical column'
    bars = sns.countplot(data=data, x=col, hue='RainTomorrow')
    keys = [key.get_text() for key in bars.get_xticklabels()]
    yes_values, no_values = bars.patches[:len(keys)], bars.patches[len(keys):]
    assert len(yes_values) == len(no_values), 'Number of yes and no values are not equal'
    
    x = {0: keys, 1: keys}
    y = {0: [v.get_height() for v in no_values], 1: [v.get_height() for v in yes_values]}
    y[0] = y[0]/sum(y[0])
    y[1] = y[1]/sum(y[1])
    plt.close()
    
    return x, y

def dist_float(data, col):
    assert col in float_cols, f'{col} is not a float column'
    kde = sns.kdeplot(data=data, x=col, hue='RainTomorrow', gridsize=1000)
    yes_line, no_line = kde.lines
    yes_x, yes_y = yes_line.get_data()
    no_x, no_y = no_line.get_data()
    
    no_y = no_y/sum(no_y)
    yes_y = yes_y/sum(yes_y)
    
    x = {0: no_x, 1: yes_x}
    y = {0: no_y, 1: yes_y}
    plt.close()
    
    return x, y

def dist_int(data, col):
    assert col in int_cols, f'{col} is not an int column'
    kde = sns.kdeplot(data=data, x=col, hue='RainTomorrow', gridsize=500)
    yes_line, no_line = kde.lines
    yes_x, yes_y = yes_line.get_data()
    no_x, no_y = no_line.get_data()
    
    yes_x = np.round(yes_x)
    no_x = np.round(no_x)
    
    new_yes_y = []
    for u in np.unique(yes_x):
        new_yes_y.append(sum(yes_y[yes_x == u]))
    
    new_no_y = []
    for u in np.unique(no_x):
        new_no_y.append(sum(no_y[no_x == u]))
    
    x = {0: np.unique(no_x), 1: np.unique(yes_x)}
    y = {0: np.array(new_no_y)/sum(new_no_y), 1: np.array(new_yes_y)/sum(new_yes_y)}
    plt.close()
    
    return x, y
        
x, y = {}, {}
for i, cols in enumerate([catetorical_cols, float_cols, int_cols]):
    dist = [dist_categorical, dist_float, dist_int][i]
    for col in cols:
        print(col)
        x[col], y[col] = dist(new_data, col)
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday'],
#       dtype='object')
# Index(['WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday'], dtype='object')
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Pressure9am',
#        'Pressure3pm', 'Temp9am', 'Temp3pm'],
#       dtype='object')
# Index(['Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm',
#        'Humidity9am', 'Humidity3pm', 'Cloud9am', 'Cloud3pm'],
#       dtype='object')
# WindGustDir
# WindDir9am
# WindDir3pm
# RainToday
# MinTemp
# MaxTemp
# Rainfall
# Evaporation
# Pressure9am
# Pressure3pm
# Temp9am
# Temp3pm
# Sunshine
# WindGustSpeed
# WindSpeed9am
# WindSpeed3pm
# Humidity9am
# Humidity3pm
# Cloud9am
# Cloud3pm

# %%
from sklearn.utils import check_array
from sklearn.utils.validation import check_is_fitted
from sklearn.base import BaseEstimator, TransformerMixin

class CustomImputer(BaseEstimator, TransformerMixin):

    def fit(self, X):
        label_col = 'RainTomorrow'
        self.X_ = X.copy()
        for col in null_columns:
            no_idx = X[(data[col].isnull()) & (X[label_col] == 'No')].index
            yes_idx = X[(data[col].isnull()) & (X[label_col] == 'Yes')].index
            
            no_impute = np.random.choice(x[col][0], size=len(no_idx), p=y[col][0])
            yes_impute = np.random.choice(x[col][1], size=len(yes_idx), p=y[col][1])
            
            self.X_.loc[no_idx, col] = no_impute
            self.X_.loc[yes_idx, col] = yes_impute
        
    def transform(self, X):
        return self.X_

# %%
imputer = CustomImputer()
imputer.fit(data)
filled_data = imputer.transform(data)
filled_data['Cloud9am'].value_counts()
# Out:
#  7.0    31025
#  1.0    24801
#  8.0    22473
#  0.0    13725
#  6.0    13255
#  2.0    10756
#  3.0     9485
#  5.0     8909
#  4.0     7074
#  9.0      413
# -1.0      277
# Name: Cloud9am, dtype: int64

# %% [markdown]
# # Visual Validation

# %%
col = ['MinTemp', 'MaxTemp']

print(f'{data[col].isnull().sum()}/{len(filled_data)}')

fig = plt.figure(figsize=(12, 8))
axes = fig.add_subplot(221), fig.add_subplot(222)

for i, ax in enumerate(axes):
    ax.set_title('Original data')
    sns.kdeplot(data=data, x=col[i], hue='RainTomorrow', ax=ax)
    
    ax = fig.add_subplot(2,2, i + 3, sharex=ax)
    ax.set_title('Imputed data')
    sns.kdeplot(data=filled_data[data.isnull().any(axis=1)], x=col[i], hue='RainTomorrow', ax=ax)
    
    plt.tight_layout()
# Out:
# MinTemp    637
# MaxTemp    322
# dtype: int64/142193

# %%
col = ['Cloud9am', 'Cloud3pm']

print(f'{data[col].isnull().sum()}/{len(filled_data)}')

fig = plt.figure(figsize=(12, 8))
axes = fig.add_subplot(221), fig.add_subplot(222)

for i, ax in enumerate(axes):
    ax.set_title('Original data')
    sns.kdeplot(data=data, x=col[i], hue='RainTomorrow', ax=ax, gridsize=10)
    
    ax = fig.add_subplot(2,2, i + 3, sharex=ax)
    ax.set_title('Imputed data')
    sns.kdeplot(data=filled_data[data.isnull().any(axis=1)], x=col[i], hue='RainTomorrow', ax=ax, gridsize=10)
    
    plt.tight_layout()
# Out:
# Cloud9am    53657
# Cloud3pm    57094
# dtype: int64/142193

# %% [markdown]
# # Preprocessing

# %%
#Date
catetorical_cols = filled_data.select_dtypes(include='object').columns
filled_data[catetorical_cols].nunique()
# Out:
# Date            3436
# Location          49
# WindGustDir       16
# WindDir9am        16
# WindDir3pm        16
# RainToday          2
# RainTomorrow       2
# dtype: int64

# %%
filled_data['Date'] = pd.to_datetime(filled_data['Date'])
filled_data['Year'] = filled_data['Date'].dt.year #datetime에서 제공하는 함수/속성
filled_data['Month'] = filled_data['Date'].dt.month
filled_data['Day'] = filled_data['Date'].dt.day

# %%
filled_data.drop('Date',axis=1, inplace=True)
filled_data.head()
# Out:
#   Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0   Albury     13.4     22.9       0.6    14.559962       8.0           W
# 1   Albury      7.4     25.1       0.0     5.680262      10.0         WNW
# 2   Albury     12.9     25.7       0.0     2.868358       8.0         WSW
# 3   Albury      9.2     28.0       0.0     5.680262      12.0          NE
# 4   Albury     17.5     32.3       1.0     5.532267       0.0           W
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Pressure3pm  Cloud9am  Cloud3pm  \
# 0           44.0          W        WNW  ...       1007.1       8.0       3.0
# 1           44.0        NNW        WSW  ...       1007.8       1.0       1.0
# 2           46.0          W        WSW  ...       1008.7       4.0       2.0
# 3           24.0         SE          E  ...       1012.8       2.0       2.0
# 4           41.0        ENE         NW  ...       1006.0       7.0       8.0
#
#    Temp9am  Temp3pm  RainToday  RainTomorrow  Year  Month  Day
# 0     16.9     21.8         No            No  2008     12    1
# 1     17.2     24.3         No            No  2008     12    2
# 2     21.0     23.2         No            No  2008     12    3
# 3     18.1     26.5         No            No  2008     12    4
# 4     17.8     29.7         No            No  2008     12    5
#
# [5 rows x 25 columns]

# %%
print(filled_data['RainTomorrow'].unique())
# Out:
# ['No' 'Yes']

# %%
sns.countplot(data=filled_data, y='Location')
# Out:
# <AxesSubplot: xlabel='count', ylabel='Location'>

# %%
le = LabelEncoder()
filled_data['WindDir3pm'] = le.fit_transform(filled_data['WindDir3pm'])
filled_data['WindDir9am'] = le.fit_transform(filled_data['WindDir9am'])
filled_data['WindGustDir'] = le.fit_transform(filled_data['WindGustDir'])
filled_data['RainToday'] = le.fit_transform(filled_data['RainToday'])
filled_data['RainTomorrow'] = le.fit_transform(filled_data['RainTomorrow'])

# %%
filled_data.groupby('Location')['RainTomorrow'].mean().sort_values(ascending=False).plot(kind='barh', figsize=(12, 8))
#cf. barh = horizontal bar
# Out:
# <AxesSubplot: ylabel='Location'>

# %% [markdown]
# ![KakaoTalk_20230110_123902677.png](attachment:KakaoTalk_20230110_123902677.png)

# %%
filled_data['Location'] = le.fit_transform(filled_data['Location'])

# %%
filled_data.head()
# Out:
#    Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0         2     13.4     22.9       0.6    14.559962       8.0           13
# 1         2      7.4     25.1       0.0     5.680262      10.0           14
# 2         2     12.9     25.7       0.0     2.868358       8.0           15
# 3         2      9.2     28.0       0.0     5.680262      12.0            4
# 4         2     17.5     32.3       1.0     5.532267       0.0           13
#
#    WindGustSpeed  WindDir9am  WindDir3pm  ...  Pressure3pm  Cloud9am  \
# 0           44.0          13          14  ...       1007.1       8.0
# 1           44.0           6          15  ...       1007.8       1.0
# 2           46.0          13          15  ...       1008.7       4.0
# 3           24.0           9           0  ...       1012.8       2.0
# 4           41.0           1           7  ...       1006.0       7.0
#
#    Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  Year  Month  Day
# 0       3.0     16.9     21.8          0             0  2008     12    1
# 1       1.0     17.2     24.3          0             0  2008     12    2
# 2       2.0     21.0     23.2          0             0  2008     12    3
# 3       2.0     18.1     26.5          0             0  2008     12    4
# 4       8.0     17.8     29.7          0             0  2008     12    5
#
# [5 rows x 25 columns]

# %%
len(filled_data.columns)
# Out:
# 25

# %%
order = ['Year', 'Month', 'Day'] 
lst = list(filled_data.columns)
order = order + lst[:-3]
order
# Out:
# ['Year',
#  'Month',
#  'Day',
#  'Location',
#  'MinTemp',
#  'MaxTemp',
#  'Rainfall',
#  'Evaporation',
#  'Sunshine',
#  'WindGustDir',
#  'WindGustSpeed',
#  'WindDir9am',
#  'WindDir3pm',
#  'WindSpeed9am',
#  'WindSpeed3pm',
#  'Humidity9am',
#  'Humidity3pm',
#  'Pressure9am',
#  'Pressure3pm',
#  'Cloud9am',
#  'Cloud3pm',
#  'Temp9am',
#  'Temp3pm',
#  'RainToday',
#  'RainTomorrow']

# %%
filled_data = filled_data.loc[:,order]
filled_data
# Out:
#         Year  Month  Day  Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008     12    1         2     13.4     22.9       0.6    14.559962
# 1       2008     12    2         2      7.4     25.1       0.0     5.680262
# 2       2008     12    3         2     12.9     25.7       0.0     2.868358
# 3       2008     12    4         2      9.2     28.0       0.0     5.680262
# 4       2008     12    5         2     17.5     32.3       1.0     5.532267
# ...      ...    ...  ...       ...      ...      ...       ...          ...
# 145454  2017      6   20        41      3.5     21.8       0.0     2.572368
# 145455  2017      6   21        41      2.8     23.4       0.0     5.532267
# 145456  2017      6   22        41      3.6     25.3       0.0     3.756328
# 145457  2017      6   23        41      5.4     26.9       0.0    12.784022
# 145458  2017      6   24        41      7.8     27.0       0.0     1.684398
#
#         Sunshine  WindGustDir  ...  Humidity9am  Humidity3pm  Pressure9am  \
# 0            8.0           13  ...         71.0         22.0       1007.7
# 1           10.0           14  ...         44.0         25.0       1010.6
# 2            8.0           15  ...         38.0         30.0       1007.6
# 3           12.0            4  ...         45.0         16.0       1017.6
# 4            0.0           13  ...         82.0         33.0       1010.8
# ...          ...          ...  ...          ...          ...          ...
# 145454       7.0            0  ...         59.0         27.0       1024.7
# 145455       7.0            0  ...         51.0         24.0       1024.6
# 145456       9.0            6  ...         56.0         21.0       1023.5
# 145457       6.0            3  ...         53.0         24.0       1021.0
# 145458       0.0            9  ...         51.0         24.0       1019.4
#
#         Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0            1007.1       8.0       3.0     16.9     21.8          0
# 1            1007.8       1.0       1.0     17.2     24.3          0
# 2            1008.7       4.0       2.0     21.0     23.2          0
# 3            1012.8       2.0       2.0     18.1     26.5          0
# 4            1006.0       7.0       8.0     17.8     29.7          0
# ...             ...       ...       ...      ...      ...        ...
# 145454       1021.2       8.0      -1.0      9.4     20.9          0
# 145455       1020.3       0.0       3.0     10.1     22.4          0
# 145456       1019.1       2.0       4.0     10.9     24.5          0
# 145457       1016.8       7.0       1.0     12.5     26.1          0
# 145458       1016.5       3.0       2.0     15.1     26.0          0
#
#         RainTomorrow
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 145454             0
# 145455             0
# 145456             0
# 145457             0
# 145458             0
#
# [142193 rows x 25 columns]

# %% [markdown]
# # Training

# %%
import tensorflow
from sklearn.preprocessing import StandardScaler
#from keras.models import Sequential
from tensorflow.keras.models import Sequential
#from keras.layers.core import Dense
from tensorflow.keras.layers import Dense

X = filled_data.drop('RainTomorrow', axis=1)
y = filled_data['RainTomorrow']

scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
model = Sequential()
model.add(Dense(30,  input_dim=24, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
           optimizer='adam',
           metrics=['accuracy'])

# %%
#from keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import EarlyStopping
# 자동 중단 설정
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=100)

# 모델 실행
model.fit(X, y, validation_split=0.2, epochs=2000, batch_size=500, callbacks=[early_stopping_callback])
# Out:
# Epoch 1/2000
# C:\Users\diana\.conda\envs\anything\lib\site-packages\keras\engine\data_adapter.py:1696: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   return t[start:end]
# 228/228 [==============================] - 2s 3ms/step - loss: 0.4179 - accuracy: 0.8117 - val_loss: 0.2893 - val_accuracy: 0.8789
# Epoch 2/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.3245 - accuracy: 0.8599 - val_loss: 0.2793 - val_accuracy: 0.8825
# Epoch 3/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.3174 - accuracy: 0.8631 - val_loss: 0.2788 - val_accuracy: 0.8818
# Epoch 4/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.3137 - accuracy: 0.8648 - val_loss: 0.2754 - val_accuracy: 0.8838
# Epoch 5/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.3110 - accuracy: 0.8655 - val_loss: 0.2762 - val_accuracy: 0.8832
# Epoch 6/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.3093 - accuracy: 0.8664 - val_loss: 0.2766 - val_accuracy: 0.8821
# Epoch 7/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.3081 - accuracy: 0.8673 - val_loss: 0.2735 - val_accuracy: 0.8829
# Epoch 8/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.3070 - accuracy: 0.8678 - val_loss: 0.2745 - val_accuracy: 0.8834
# Epoch 9/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.3063 - accuracy: 0.8679 - val_loss: 0.2760 - val_accuracy: 0.8840
# Epoch 10/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.3053 - accuracy: 0.8680 - val_loss: 0.2754 - val_accuracy: 0.8820
# Epoch 11/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.3045 - accuracy: 0.8688 - val_loss: 0.2748 - val_accuracy: 0.8832
# Epoch 12/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.3038 - accuracy: 0.8689 - val_loss: 0.2750 - val_accuracy: 0.8840
# Epoch 13/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.3033 - accuracy: 0.8689 - val_loss: 0.2740 - val_accuracy: 0.8820
# Epoch 14/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.3026 - accuracy: 0.8692 - val_loss: 0.2764 - val_accuracy: 0.8816
# Epoch 15/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.3021 - accuracy: 0.8697 - val_loss: 0.2734 - val_accuracy: 0.8829
# Epoch 16/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.3016 - accuracy: 0.8692 - val_loss: 0.2745 - val_accuracy: 0.8831
# Epoch 17/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.3011 - accuracy: 0.8700 - val_loss: 0.2748 - val_accuracy: 0.8832
# Epoch 18/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.3007 - accuracy: 0.8698 - val_loss: 0.2745 - val_accuracy: 0.8829
# Epoch 19/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.3003 - accuracy: 0.8700 - val_loss: 0.2743 - val_accuracy: 0.8832
# Epoch 20/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2998 - accuracy: 0.8702 - val_loss: 0.2739 - val_accuracy: 0.8826
# Epoch 21/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2994 - accuracy: 0.8702 - val_loss: 0.2749 - val_accuracy: 0.8835
# Epoch 22/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2990 - accuracy: 0.8704 - val_loss: 0.2762 - val_accuracy: 0.8830
# Epoch 23/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2986 - accuracy: 0.8701 - val_loss: 0.2781 - val_accuracy: 0.8826
# Epoch 24/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2983 - accuracy: 0.8708 - val_loss: 0.2742 - val_accuracy: 0.8834
# Epoch 25/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2982 - accuracy: 0.8707 - val_loss: 0.2762 - val_accuracy: 0.8829
# Epoch 26/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2978 - accuracy: 0.8711 - val_loss: 0.2749 - val_accuracy: 0.8830
# Epoch 27/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2976 - accuracy: 0.8711 - val_loss: 0.2759 - val_accuracy: 0.8831
# Epoch 28/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2973 - accuracy: 0.8712 - val_loss: 0.2749 - val_accuracy: 0.8830
# Epoch 29/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2970 - accuracy: 0.8710 - val_loss: 0.2779 - val_accuracy: 0.8817
# Epoch 30/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2967 - accuracy: 0.8717 - val_loss: 0.2740 - val_accuracy: 0.8825
# Epoch 31/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2965 - accuracy: 0.8716 - val_loss: 0.2757 - val_accuracy: 0.8826
# Epoch 32/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2962 - accuracy: 0.8712 - val_loss: 0.2754 - val_accuracy: 0.8834
# Epoch 33/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2959 - accuracy: 0.8712 - val_loss: 0.2758 - val_accuracy: 0.8832
# Epoch 34/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2957 - accuracy: 0.8717 - val_loss: 0.2763 - val_accuracy: 0.8826
# Epoch 35/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2954 - accuracy: 0.8718 - val_loss: 0.2734 - val_accuracy: 0.8828
# Epoch 36/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2953 - accuracy: 0.8717 - val_loss: 0.2748 - val_accuracy: 0.8830
# Epoch 37/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2952 - accuracy: 0.8718 - val_loss: 0.2755 - val_accuracy: 0.8819
# Epoch 38/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2948 - accuracy: 0.8719 - val_loss: 0.2757 - val_accuracy: 0.8830
# Epoch 39/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2947 - accuracy: 0.8719 - val_loss: 0.2764 - val_accuracy: 0.8825
# Epoch 40/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2944 - accuracy: 0.8724 - val_loss: 0.2747 - val_accuracy: 0.8837
# Epoch 41/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2943 - accuracy: 0.8719 - val_loss: 0.2770 - val_accuracy: 0.8827
# Epoch 42/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2941 - accuracy: 0.8726 - val_loss: 0.2749 - val_accuracy: 0.8833
# Epoch 43/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2941 - accuracy: 0.8723 - val_loss: 0.2764 - val_accuracy: 0.8829
# Epoch 44/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2939 - accuracy: 0.8722 - val_loss: 0.2740 - val_accuracy: 0.8829
# Epoch 45/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2936 - accuracy: 0.8725 - val_loss: 0.2744 - val_accuracy: 0.8827
# Epoch 46/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2937 - accuracy: 0.8724 - val_loss: 0.2766 - val_accuracy: 0.8824
# Epoch 47/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2935 - accuracy: 0.8727 - val_loss: 0.2740 - val_accuracy: 0.8838
# Epoch 48/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2932 - accuracy: 0.8728 - val_loss: 0.2738 - val_accuracy: 0.8829
# Epoch 49/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2931 - accuracy: 0.8721 - val_loss: 0.2764 - val_accuracy: 0.8830
# Epoch 50/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2931 - accuracy: 0.8726 - val_loss: 0.2769 - val_accuracy: 0.8824
# Epoch 51/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2930 - accuracy: 0.8725 - val_loss: 0.2754 - val_accuracy: 0.8829
# Epoch 52/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2927 - accuracy: 0.8725 - val_loss: 0.2758 - val_accuracy: 0.8828
# Epoch 53/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2925 - accuracy: 0.8732 - val_loss: 0.2722 - val_accuracy: 0.8835
# Epoch 54/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2926 - accuracy: 0.8734 - val_loss: 0.2734 - val_accuracy: 0.8834
# Epoch 55/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2925 - accuracy: 0.8733 - val_loss: 0.2774 - val_accuracy: 0.8819
# Epoch 56/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2926 - accuracy: 0.8733 - val_loss: 0.2727 - val_accuracy: 0.8833
# Epoch 57/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2922 - accuracy: 0.8734 - val_loss: 0.2748 - val_accuracy: 0.8835
# Epoch 58/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2921 - accuracy: 0.8734 - val_loss: 0.2750 - val_accuracy: 0.8839
# Epoch 59/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2920 - accuracy: 0.8740 - val_loss: 0.2768 - val_accuracy: 0.8834
# Epoch 60/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2920 - accuracy: 0.8736 - val_loss: 0.2762 - val_accuracy: 0.8827
# Epoch 61/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2918 - accuracy: 0.8740 - val_loss: 0.2771 - val_accuracy: 0.8825
# Epoch 62/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2917 - accuracy: 0.8737 - val_loss: 0.2729 - val_accuracy: 0.8833
# Epoch 63/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2919 - accuracy: 0.8733 - val_loss: 0.2760 - val_accuracy: 0.8834
# Epoch 64/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2916 - accuracy: 0.8735 - val_loss: 0.2742 - val_accuracy: 0.8837
# Epoch 65/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2916 - accuracy: 0.8734 - val_loss: 0.2776 - val_accuracy: 0.8823
# Epoch 66/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2913 - accuracy: 0.8739 - val_loss: 0.2771 - val_accuracy: 0.8823
# Epoch 67/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2912 - accuracy: 0.8738 - val_loss: 0.2782 - val_accuracy: 0.8822
# Epoch 68/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2913 - accuracy: 0.8740 - val_loss: 0.2768 - val_accuracy: 0.8825
# Epoch 69/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2915 - accuracy: 0.8740 - val_loss: 0.2757 - val_accuracy: 0.8820
# Epoch 70/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2912 - accuracy: 0.8742 - val_loss: 0.2754 - val_accuracy: 0.8822
# Epoch 71/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2910 - accuracy: 0.8742 - val_loss: 0.2771 - val_accuracy: 0.8822
# Epoch 72/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2909 - accuracy: 0.8740 - val_loss: 0.2754 - val_accuracy: 0.8825
# Epoch 73/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2908 - accuracy: 0.8742 - val_loss: 0.2774 - val_accuracy: 0.8827
# Epoch 74/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2908 - accuracy: 0.8741 - val_loss: 0.2776 - val_accuracy: 0.8828
# Epoch 75/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2907 - accuracy: 0.8745 - val_loss: 0.2757 - val_accuracy: 0.8835
# Epoch 76/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2907 - accuracy: 0.8741 - val_loss: 0.2740 - val_accuracy: 0.8836
# Epoch 77/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2904 - accuracy: 0.8749 - val_loss: 0.2753 - val_accuracy: 0.8827
# Epoch 78/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2906 - accuracy: 0.8746 - val_loss: 0.2767 - val_accuracy: 0.8829
# Epoch 79/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2904 - accuracy: 0.8746 - val_loss: 0.2768 - val_accuracy: 0.8821
# Epoch 80/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2904 - accuracy: 0.8745 - val_loss: 0.2800 - val_accuracy: 0.8816
# Epoch 81/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2903 - accuracy: 0.8742 - val_loss: 0.2764 - val_accuracy: 0.8827
# Epoch 82/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2902 - accuracy: 0.8747 - val_loss: 0.2766 - val_accuracy: 0.8826
# Epoch 83/2000
# 228/228 [==============================] - 0s 2ms/step - loss: 0.2902 - accuracy: 0.8747 - val_loss: 0.2746 - val_accuracy: 0.8833
# Epoch 84/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2901 - accuracy: 0.8744 - val_loss: 0.2746 - val_accuracy: 0.8827
# Epoch 85/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2899 - accuracy: 0.8742 - val_loss: 0.2758 - val_accuracy: 0.8828
# Epoch 86/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2898 - accuracy: 0.8752 - val_loss: 0.2794 - val_accuracy: 0.8821
# Epoch 87/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2898 - accuracy: 0.8749 - val_loss: 0.2795 - val_accuracy: 0.8825
# Epoch 88/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2898 - accuracy: 0.8750 - val_loss: 0.2749 - val_accuracy: 0.8831
# Epoch 89/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2898 - accuracy: 0.8747 - val_loss: 0.2784 - val_accuracy: 0.8817
# Epoch 90/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2897 - accuracy: 0.8746 - val_loss: 0.2760 - val_accuracy: 0.8818
# Epoch 91/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2896 - accuracy: 0.8750 - val_loss: 0.2749 - val_accuracy: 0.8822
# Epoch 92/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2896 - accuracy: 0.8749 - val_loss: 0.2787 - val_accuracy: 0.8820
# Epoch 93/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2895 - accuracy: 0.8752 - val_loss: 0.2774 - val_accuracy: 0.8821
# Epoch 94/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2894 - accuracy: 0.8747 - val_loss: 0.2770 - val_accuracy: 0.8832
# Epoch 95/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2894 - accuracy: 0.8754 - val_loss: 0.2758 - val_accuracy: 0.8825
# Epoch 96/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2896 - accuracy: 0.8753 - val_loss: 0.2752 - val_accuracy: 0.8832
# Epoch 97/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2893 - accuracy: 0.8748 - val_loss: 0.2757 - val_accuracy: 0.8828
# Epoch 98/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2892 - accuracy: 0.8750 - val_loss: 0.2787 - val_accuracy: 0.8820
# Epoch 99/2000
# 228/228 [==============================] - 0s 2ms/step - loss: 0.2894 - accuracy: 0.8750 - val_loss: 0.2780 - val_accuracy: 0.8826
# Epoch 100/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2892 - accuracy: 0.8755 - val_loss: 0.2797 - val_accuracy: 0.8824
# Epoch 101/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2893 - accuracy: 0.8752 - val_loss: 0.2756 - val_accuracy: 0.8829
# Epoch 102/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2892 - accuracy: 0.8749 - val_loss: 0.2758 - val_accuracy: 0.8821
# Epoch 103/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2890 - accuracy: 0.8753 - val_loss: 0.2775 - val_accuracy: 0.8822
# Epoch 104/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2891 - accuracy: 0.8749 - val_loss: 0.2747 - val_accuracy: 0.8828
# Epoch 105/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2890 - accuracy: 0.8750 - val_loss: 0.2743 - val_accuracy: 0.8829
# Epoch 106/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2889 - accuracy: 0.8752 - val_loss: 0.2731 - val_accuracy: 0.8835
# Epoch 107/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2887 - accuracy: 0.8752 - val_loss: 0.2756 - val_accuracy: 0.8822
# Epoch 108/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2889 - accuracy: 0.8754 - val_loss: 0.2770 - val_accuracy: 0.8829
# Epoch 109/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2886 - accuracy: 0.8753 - val_loss: 0.2796 - val_accuracy: 0.8811
# Epoch 110/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2887 - accuracy: 0.8752 - val_loss: 0.2767 - val_accuracy: 0.8824
# Epoch 111/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2887 - accuracy: 0.8755 - val_loss: 0.2751 - val_accuracy: 0.8825
# Epoch 112/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2888 - accuracy: 0.8750 - val_loss: 0.2800 - val_accuracy: 0.8806
# Epoch 113/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2886 - accuracy: 0.8751 - val_loss: 0.2821 - val_accuracy: 0.8810
# Epoch 114/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2889 - accuracy: 0.8754 - val_loss: 0.2754 - val_accuracy: 0.8827
# Epoch 115/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2885 - accuracy: 0.8750 - val_loss: 0.2783 - val_accuracy: 0.8826
# Epoch 116/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2885 - accuracy: 0.8749 - val_loss: 0.2764 - val_accuracy: 0.8825
# Epoch 117/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2884 - accuracy: 0.8754 - val_loss: 0.2749 - val_accuracy: 0.8831
# Epoch 118/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2885 - accuracy: 0.8752 - val_loss: 0.2734 - val_accuracy: 0.8831
# Epoch 119/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2884 - accuracy: 0.8748 - val_loss: 0.2776 - val_accuracy: 0.8826
# Epoch 120/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2884 - accuracy: 0.8751 - val_loss: 0.2778 - val_accuracy: 0.8823
# Epoch 121/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2884 - accuracy: 0.8756 - val_loss: 0.2757 - val_accuracy: 0.8825
# Epoch 122/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2886 - accuracy: 0.8752 - val_loss: 0.2780 - val_accuracy: 0.8817
# Epoch 123/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2882 - accuracy: 0.8753 - val_loss: 0.2762 - val_accuracy: 0.8821
# Epoch 124/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2885 - accuracy: 0.8751 - val_loss: 0.2755 - val_accuracy: 0.8825
# Epoch 125/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2882 - accuracy: 0.8751 - val_loss: 0.2759 - val_accuracy: 0.8834
# Epoch 126/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2881 - accuracy: 0.8754 - val_loss: 0.2760 - val_accuracy: 0.8817
# Epoch 127/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2883 - accuracy: 0.8749 - val_loss: 0.2768 - val_accuracy: 0.8824
# Epoch 128/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2881 - accuracy: 0.8751 - val_loss: 0.2752 - val_accuracy: 0.8834
# Epoch 129/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2880 - accuracy: 0.8757 - val_loss: 0.2752 - val_accuracy: 0.8825
# Epoch 130/2000
# 228/228 [==============================] - 1s 2ms/step - loss: 0.2880 - accuracy: 0.8754 - val_loss: 0.2804 - val_accuracy: 0.8814
# Epoch 131/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2880 - accuracy: 0.8754 - val_loss: 0.2770 - val_accuracy: 0.8820
# Epoch 132/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2880 - accuracy: 0.8756 - val_loss: 0.2752 - val_accuracy: 0.8817
# Epoch 133/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2877 - accuracy: 0.8759 - val_loss: 0.2734 - val_accuracy: 0.8827
# Epoch 134/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2880 - accuracy: 0.8749 - val_loss: 0.2752 - val_accuracy: 0.8827
# Epoch 135/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2879 - accuracy: 0.8755 - val_loss: 0.2765 - val_accuracy: 0.8827
# Epoch 136/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2878 - accuracy: 0.8753 - val_loss: 0.2771 - val_accuracy: 0.8828
# Epoch 137/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2877 - accuracy: 0.8760 - val_loss: 0.2781 - val_accuracy: 0.8807
# Epoch 138/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2878 - accuracy: 0.8754 - val_loss: 0.2754 - val_accuracy: 0.8821
# Epoch 139/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2877 - accuracy: 0.8756 - val_loss: 0.2746 - val_accuracy: 0.8831
# Epoch 140/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2876 - accuracy: 0.8753 - val_loss: 0.2753 - val_accuracy: 0.8829
# Epoch 141/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2875 - accuracy: 0.8755 - val_loss: 0.2776 - val_accuracy: 0.8824
# Epoch 142/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2879 - accuracy: 0.8759 - val_loss: 0.2747 - val_accuracy: 0.8828
# Epoch 143/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2877 - accuracy: 0.8752 - val_loss: 0.2775 - val_accuracy: 0.8822
# Epoch 144/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2876 - accuracy: 0.8758 - val_loss: 0.2748 - val_accuracy: 0.8818
# Epoch 145/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2874 - accuracy: 0.8759 - val_loss: 0.2746 - val_accuracy: 0.8815
# Epoch 146/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2876 - accuracy: 0.8756 - val_loss: 0.2787 - val_accuracy: 0.8816
# Epoch 147/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2875 - accuracy: 0.8758 - val_loss: 0.2784 - val_accuracy: 0.8817
# Epoch 148/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2873 - accuracy: 0.8760 - val_loss: 0.2751 - val_accuracy: 0.8821
# Epoch 149/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2874 - accuracy: 0.8757 - val_loss: 0.2763 - val_accuracy: 0.8810
# Epoch 150/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2874 - accuracy: 0.8754 - val_loss: 0.2759 - val_accuracy: 0.8817
# Epoch 151/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2874 - accuracy: 0.8753 - val_loss: 0.2754 - val_accuracy: 0.8819
# Epoch 152/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2874 - accuracy: 0.8757 - val_loss: 0.2758 - val_accuracy: 0.8817
# Epoch 153/2000
# 228/228 [==============================] - 1s 3ms/step - loss: 0.2871 - accuracy: 0.8759 - val_loss: 0.2756 - val_accuracy: 0.8817

# %%
# 결과 출력
print("\n Accuracy: %.4f" % (model.evaluate(X, y)[1]))
# Out:
# 4444/4444 [==============================] - 8s 2ms/step - loss: 0.2845 - accuracy: 0.8769
#
#  Accuracy: 0.8769

# %%
import tensorflow as tf

# %%
#from tensorflow import keras

model.summary()
tf.keras.utils.plot_model(model, "myModel.png", show_shapes=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 30)                750
#
#  dense_5 (Dense)             (None, 12)                372
#
#  dense_6 (Dense)             (None, 8)                 104
#
#  dense_7 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 1,235
# Trainable params: 1,235
# Non-trainable params: 0
# _________________________________________________________________
